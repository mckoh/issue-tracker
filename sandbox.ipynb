# %%
from app import add_issue, set_issue_to_done, initialize_database, get_issues

# %%
initialize_database("issue_tracker.db")
add_issue("Test", "Test Description", "2026-04-26")
get_issues()
set_issue_to_done(4)
